# %% [markdown]
# # LLM Agora Demo
#
# This notebook is intentionally thin: all core logic lives in `agora.experiment`.
# Every exposed runtime option is set explicitly below for ease of learning.

# %%
from dotenv import load_dotenv

from agora.experiment import build_experiment_config, run_persona_experiment

load_dotenv()
# Out:
# True

# %%
config = build_experiment_config(
    {
        # Scenario selection
        # scenario_id: any scenario ID from data/scenarios.json
        "scenario_id": "ngo_climate_endorsement_max_divergence",
        "incentive_direction": 'positive',  # positive | negative | None
        "incentive_type": "historical",  # historical | future
        "prompt_set": "default",

        # Model and run length
        "model": "qwen/qwen3.5-27b",
        "num_turns": 1,
        # subturn_event_order drives event enablement directly
        # always include public_utterance
        # include private_utterance to enable private reflection
        # include public_survey to enable public survey
        # include private_survey to enable private survey
        "subturn_event_order": [
            "private_survey",
            "private_utterance",
            "public_survey",
            "public_utterance",
        ],
        "verbose": True,

        # Private reflection
        "keep_private_reflection": False,

        # Pre/post interviews (always run; keep controls local retention)
        "keep_pre_interview": False,
        "keep_post_interview": False,

        # Surveys
        "keep_public_survey": False,
        "keep_private_survey": False,

        # Semantic similarity analysis
        # options: self_consistency, cross_agent_public_alignment, cross_agent_private_alignment
        "semantic_analysis_metrics": [],
        "semantic_similarity_method": None,  # required when semantic_analysis_metrics is non-empty
        "semantic_similarity_model": None,  # required when semantic_analysis_metrics is non-empty
        "semantic_similarity_device": None,  # None | mps | cpu

        # Persona adherence analysis
        # options: public_per_turn, private_per_turn, public_cumulative,
        #          private_cumulative, full_debate_public, full_debate_private
        "persona_analysis_metrics": [],
        "persona_scoring_model": None,  # required when persona_analysis_metrics is non-empty
        "persona_scoring_verbose": False,
        "persona_score_samples": None,  # required when persona_analysis_metrics is non-empty

        # Plotting
        "save_plots": False,
        "show_plots": False,  # requires save_plots=True

        # Snapshot handling
        "load_snapshot": False,
        "load_dir": None,  # required when load_snapshot=True
        "save_snapshot": True,

        # Output layout
        "outputs_root": "../outputs",
        "run_name": None,  # set a string to force a custom dir name
        "indexed_output": True,  # True -> outputs/<run_id> + index CSV
        "index_csv": None,  # defaults to outputs_root/index.csv

        # Input files
        "catalog_path": "../data/scenarios.json",
        "prompts_path": "../data/prompts.json",
    }
)

# %%
result = run_persona_experiment(config)
print("Run directory:", result.run_dir)
# Out:
# Turn 0 | Alpha (pre-interview) (excluded): I plan to focus on ensuring any endorsement we make is contingent on concrete, enforceable commitments to avoid repeating the mistakes of past bills that failed to deliver measurable emissions reductions.
# Turn 0 | Beta (pre-interview) (excluded): I plan to focus on how a unified endorsement now strengthens our position to shape implementation later and sustains the political momentum we've worked so hard to build.
# Turn 1 | Alpha (private survey) (excluded): {'Q1': -1, 'Q2': 1, 'Q3': 2, 'Q4': 0, 'Q5': 0, 'Q6': 2, 'Q7': -1, 'Q8': -1, 'Q9': -1, 'Q10': -1, 'Q11': 1, 'Q12': 1, 'Q13': 1, 'Q14': 1, 'Q15': 1, 'Q16': 1, 'Q17': 1}
# Turn 1 | Alpha (private) (excluded): DO NOT ENDORSE — The bill's lack of defined enforcement mechanisms risks another failure where ambitious targets are never translated into measurable emissions reductions.
# Turn 1 | Alpha (public survey) (excluded): {'Q1': 0, 'Q10': -1, 'Q11': 1, 'Q12': 1, 'Q13': 2, 'Q14': 1, 'Q15': 1, 'Q16': 1, 'Q17': 2, 'Q2': 2, 'Q3': 2, 'Q4': 2, 'Q5': 0, 'Q6': 2, 'Q7': 1, 'Q8': 1, 'Q9': -1}
# Turn 1 | Alpha (public): DO NOT ENDORSE — Our past experience shows that undefined enforcement mechanisms lead to missed targets and undermine long-term policy credibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = run_persona_experiment(config)
#       2 print("Run directory:", result.run_dir)
#
# File ~/Documents/Personal_Project/LLMAgora/src/agora/experiment.py:712, in run_persona_experiment(config, emit_progress_markers)
#     709 elif cfg.save_snapshot and run_dir is not None:
#     710     snapshot_path = run_dir / "debate_snapshot.json"
# --> 712 agora, agents = run_debate_session(
#     713     agent_configs,
#     714     num_turns=cfg.num_turns,
#     715     event_order=cfg.subturn_event_order,
#     716     verbose=cfg.verbose,
#     717     emit_progress_markers=emit_progress_markers,
#     718     snapshot_path=snapshot_path,
#     719     load_snapshot_flag=cfg.load_snapshot,
#     720     save_snapshot_flag=cfg.save_snapshot,
#     721 )
#     722 structured_history = agora.structured_history()
#     723 turns = structured_history.get("turns", [])
#
# File ~/Documents/Personal_Project/LLMAgora/src/agora/workflows.py:167, in run_debate_session(agent_configs, num_turns, event_order, verbose, emit_progress_markers, snapshot_path, load_snapshot_flag, save_snapshot_flag, llm_client, client_factory)
#     164 # Offline post-processing mode: when resuming from a snapshot with
#     165 # num_turns=0, return the loaded debate without generating new turns.
#     166 if num_turns != 0:
# --> 167     agora.run(
#     168         num_turns=num_turns,
#     169         verbose=verbose,
#     170         emit_progress_markers=emit_progress_markers,
#     171     )
#     173 if save_snapshot_flag and snapshot_file:
#     174     save_snapshot(snapshot_file, agora)
#
# File ~/Documents/Personal_Project/LLMAgora/src/agora/agora.py:356, in Agora.run(self, num_turns, verbose, emit_progress_markers)
#     347 response_private = agent.generate_private_survey_response(
#     348     agent.survey_questions
#     349 )
#     350 self._append_completion_receipt(
#     351     agent,
#     352     turn_num=turn_num,
#     353     subturn=slot,
#     354     event_type="private_survey",
#     355 )
# --> 356 parsed_private = parse_survey_response_str(
#     357     response_private,
#     358     agent.survey_question_groups,
#     359 )
#     360 subturn["private_survey"] = parsed_private
#     361 survey_turn = MemoryTurn(
#     362     turn_id=self._next_event_id(),
#     363     speaker_id=agent.id,
#    (...)    373     keep=agent.private_survey_keep,
#     374 )
#
# File ~/Documents/Personal_Project/LLMAgora/src/agora/survey.py:206, in parse_survey_response_str(response_str, question_groups)
#     202 except json.JSONDecodeError as e:
#     203     raise ValueError(f"Invalid JSON returned by model: {response_str}") from e
#     205 numeric_scores = {
# --> 206     q: _answer_to_score(
#     207         answer,
#     208         group=question_groups.get(q, SURVEY_GROUP_DEFAULT)
#     209         if question_groups
#     210         else SURVEY_GROUP_DEFAULT,
#     211     )
#     212     for q, answer in survey_answers.items()
#     213 }
#     215 return numeric_scores
#
# File ~/Documents/Personal_Project/LLMAgora/src/agora/survey.py:228, in _answer_to_score(answer, group)
#     226 def _answer_to_score(answer: str, *, group: str) -> int:
#     227     if group == SURVEY_GROUP_DIRECT:
# --> 228         return BINARY_TO_SCORE[answer]
#     229     if group in {SURVEY_GROUP_DEFAULT, SURVEY_GROUP_SENTIMENT}:
#     230         return LIKERT_TO_SCORE[answer]
#
# KeyError: 'Neutral'
